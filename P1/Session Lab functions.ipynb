# %% [markdown]
# # Defining and Using Functions session 3-1

# %% [markdown]
# Basic Function Definition and Call

# %%
def greet():
    print("Hello, world!")
    print("Thanks")

greet()
# Out:
# Hello, world!
# Thanks

# %% [markdown]
# Function with Parameters

# %%
def add(x,y):
    print(x+y)

add(10,5)
# Out:
# 15

# %%
int(input())

# %%
def add(a, b):
    return a + b

result = add(5, 3)
print("Sum:", result)
# Out:
# Sum: 8

# %% [markdown]
# Function with Default Parameter Values

# %%
def greet(name="Guest"):
    print(f"Hello, {name}!")

greet("Alice")
greet()
# Out:
# Hello, Alice!
# Hello, Guest!

# %% [markdown]
# Function Divide Returning Multiple Values

# %%
def div(num1,num2): #20,3 
    result=num1 // num2
    remain=num1 % num2
    print(f'the result =  {result} and the remain = {remain}')

# %%
div(20,3)
# Out:
# the result =  6 and the remain = 2

# %%
def divide(a, b):
    quotient = a // b
    remainder = a % b
    return quotient, remainder

q, r = divide(10, 3)
print("Quotient:", q)
print("Remainder:", r)
# Out:
# Quotient: 3
# Remainder: 1

# %% [markdown]
# # Advanced Function Concepts

# %% [markdown]
# **Lambda Functions**

# %% [markdown]
# Basic Lambda Function

# %%
square = lambda x: x ** 2
print(square(5))
# Out:
# 25

# %%
def square(x):
    print(x**2)
square(5)
# Out:
# 25

# %% [markdown]
# Lambda Function with Multiple Arguments

# %%
multiply = lambda x, y: x * y
print(multiply(3, 4))
# Out:
# 12

# %% [markdown]
# Using Lambda in map() Function

# %%
numbers = [1, 2, 3, 4, 5]
squares = list(map(lambda x: x ** 2, numbers)) #map( p1,p2)
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# Using Lambda in filter() Function

# %%
numbers = [1, 2, 3, 4, 5, 6]
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)
# Out:
# [2, 4, 6]

# %%
Orign_tuple=(1,2,3)
Result="".join(map(str,Orign_tuple))
Final_result=int(Result)
print(Final_result)
# Out:
# 123

# %%
Orign_tuple=(1,2,3)
vr=0
last=len(Orign_tuple)-1
po=1

# %% [markdown]
# **Recursive Functions**

# %% [markdown]
# Calculating Factorial Using Recursion

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)

print(factorial(5))
# Out:
# 120

# %% [markdown]
# Fibonacci Sequence Using Recursion

# %%
def fibonacci(n):
    if n <= 1:
        return n
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

print(fibonacci(6))
# Out:
# 8

# %% [markdown]
# **Higher-Order Functions**

# %% [markdown]
# Using a Function as an Argument

# %%
def apply_operation(a, b, operation):
    return operation(a, b)

def add(x, y):
    return x + y

def sub(x,y):
    return x-y

print(apply_operation(5, 3, sub))
# Out:
# 2

# %% [markdown]
# Returning a Function from Another Function

# %%
def outer_function(message):
    def inner_function():
        print(message)
    return inner_function

greet = outer_function("Hello!")
greet()
# Out:
# Hello!

# %% [markdown]
# # Practical Examples

# %% [markdown]
# Calculating Average of Numbers Using Functions

# %%
def calculate_average(numbers):
    return sum(numbers) / len(numbers)

numbers = [10, 20, 30, 40, 50]
print("Average:", calculate_average(numbers))
# Out:
# Average: 30.0

# %% [markdown]
# Finding the Longest Word in a List

# %%
def find_longest_word(words):
    longest = ""
    for word in words:
        if len(word) > len(longest):
            longest = word
    return longest

words = ["apple", "banana", "cherry", "date"]
print("Longest word:", find_longest_word(words))
# Out:
# Longest word: banana

# %% [markdown]
# Checking if a Number is Prime

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

print("Is 17 prime?", is_prime(17))
# Out:
# Is 17 prime? True

# %% [markdown]
# Converting Temperature Units

# %%
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

def fahrenheit_to_celsius(fahrenheit):
    return (fahrenheit - 32) * 5/9

print("25°C to Fahrenheit:", celsius_to_fahrenheit(25))
print("77°F to Celsius:", fahrenheit_to_celsius(77))
# Out:
# 25°C to Fahrenheit: 77.0
# 77°F to Celsius: 25.0

# %% [markdown]
# Generating a List of Squares Using List Comprehension and Functions

# %%
def square_list(numbers):
    return [x ** 2 for x in numbers]

numbers = [1, 2, 3, 4, 5]
print("List of squares:", square_list(numbers))
# Out:
# List of squares: [1, 4, 9, 16, 25]

# %% [markdown]
# Converting a List of Strings to Uppercase

# %%
def convert_to_uppercase(words):
    return [word.upper() for word in words]

words = ["hello", "world", "python", "functions"]
print("Uppercase words:", convert_to_uppercase(words))
# Out:
# Uppercase words: ['HELLO', 'WORLD', 'PYTHON', 'FUNCTIONS']

# %% [markdown]
# Calculating the Total Price Including Tax

# %%
def calculate_total_price(prices, tax_rate):
    total = sum(prices)
    total_with_tax = total * (1 + tax_rate)
    return total_with_tax

prices = [100, 200, 300]
tax_rate = 0.1
print("Total price with tax:", calculate_total_price(prices, tax_rate))
# Out:
# Total price with tax: 660.0

# %% [markdown]
# Finding the Minimum and Maximum Values in a List

# %%
def find_min_max(numbers):
    return min(numbers), max(numbers)

numbers = [3, 7, 2, 9, 4]
min_value, max_value = find_min_max(numbers)
print("Minimum value:", min_value)
print("Maximum value:", max_value)
# Out:
# Minimum value: 2
# Maximum value: 9

# %% [markdown]
# Checking if a String is a Valid Email Address

# %%
def is_valid_email(email):
    return "@" in email and "." in email.split("@")[-1]

email = "example@example.com"
print("Is valid email:", is_valid_email(email))
# Out:
# Is valid email: True

# %% [markdown]
# Counting the Frequency of Each Character in a String

# %%
def count_character_frequency(text):
    frequency = {}
    for char in text:
        if char in frequency:
            frequency[char] += 1
        else:
            frequency[char] = 1
    return frequency

text = "hello world"
print("Character frequency:", count_character_frequency(text))
# Out:
# Character frequency: {'h': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 1, 'w': 1, 'r': 1, 'd': 1}

# %%
original_tuple = (1, 2, 3)
converted_integer = 0
for digit in original_tuple:
    converted_integer = converted_integer *10 + digit
print("Converted integer:", converted_integer)
# Out:
# Converted integer: 123

# %%
original_tuple = (1, 2, 3)
new=int(str(original_tuple[0])+str(original_tuple[1])+str(original_tuple[2]))
print('The integer is',new)
# Out:
# The integer is 123

# %%
import S11
usernames = ['max', 'samy', 'mahmoud']
S11.say_hello_username(usernames)
# Out:
# Hello, Max!
# Hello, Samy!
# Hello, Mahmoud!
