# %%
import numpy as np

print(np.__version__)
# Out:
# 2.4.1

# %%
arr2 = np.array([[1, 2, 3], 
                 [4, 5, 6],
                [10,11,12]])
print(arr2)
print(arr2.shape)
print(arr2.ndim)
# Out:
# [[ 1  2  3]
#  [ 4  5  6]
#  [10 11 12]]
# (3, 3)
# 2

# %%
print(arr2[1, 2])  # Accessing element at row 1, column 2

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#
# File c:\Users\Farouk sameh\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\__init__.py:56
#      46 from pandas._config import (
#      47     get_option,
#      48     set_option,
#    (...)     52     options,
#      53 )
#      55 # let init-time option registration happen
# ---> 56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#    (...)    119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#
# File c:\Users\Farouk sameh\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\config_init.py:31
#      19 import pandas._config.config as cf
#      20 from pandas._config.config import (
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35],
        'City': ['New York', 'Los Angeles', 'Chicago']}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 823.6 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 881.4 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 924.3 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 924.3 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 873.8 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 912.5 kB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 958.8 kB/s  0:00:02
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
# ...

# %%
arr= np.array([[1, 2],
               [3, 4]])
arr=arr+5
print(arr)
